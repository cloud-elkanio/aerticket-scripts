# %%
kwargs = {'booking_items': [{'room_code': '4dhflnri4qwcpubuy7xq', 'rate_key': '4phfnmjx4ius7fstusmwehgw4ljohjxe6gzo3htz3bgrd6pkl2yar67pk5swleeqs5ffz6xtv54bqebxxcygq5m72pobjl6hsgusxq6w4gofftcrzj5d6oatei3oepck7g6sv3tfdazrk74j7g2murp44ky3ewesa34uppc47bey5wxwaewsbai7s6cgd7irblpr2wimajisapw5xkahnqrhvxhebzowb3nwxb4po2ini6okh7zxevzkmcka', 'room_reference': 'qk4srkscrircpwy', 'paxes': [{'title': 'Mr.', 'first_name': 'Jijo', 'last_name': 'Thomas', 'email': None, 'mobile_no': None, 'type': None}]}], 'check_in': '2025-10-12', 'check_out': '2025-10-20', 'group_code': 'xgirbylkwb6xtgj647fdssmex6nkls5j6c6ojv3y', 'city_code': '120919', 'search_id': '7s263wrkl3nkmxqsxusczoiuqq', 'hotel_code': '1380443', 'headers': {'api-key': 'bab29dcd81b9be82284efc966fdbdbaf', 'Accept': 'application/json', 'Content-Type': 'application/json'}, 'base_url': 'https://api-sandbox.grnconnect.com/api/v3/hotels', 'holder_details': {'title': 'Mr.', 'name': 'John', 'surname': 'Doe', 'email': 'john.doe@example.com', 'phone_number': '9876543210', 'client_nationality': 'In', 'pan_number': 'ABCDE1234F', 'pan_company_name': 'elkanio', 'fema_declaration': True}, 'payment_type': 'AT_WEB'}

# %%
import json

import requests
rate_key = {            
    # "rate_key": "4phfnmjx4ius7fstusmwehgw4ljohjxe6gzo3htz3bgrd6pkl2yar67pk5swleeqs5ffz6xtv54bqebxxcygq5m72pobjl6hsgusxq6w4gofftcrzj4tonaqfuyogo2f7g6sv3tfdazrk74j7lalurum4gz3oj4wo2fupm2y7bey5wxwaassvbarswewd7irblpr2wimajisapw5xkahnqrhvxhebzowb3nwxb4po2ini6okh7zxevzkmcka",
    "rate_key": "4phfnmjx4ius7fstusmwehgw4ljohjxe6gzo3htz3bgrd6pkl2yar67pk5swleeqs5ffz6xtv54bqebuxcygq5m72pobjl6hsgusxqef46nvjtcnyj5tmnixei36moadzggsv3svdexds75u6hb3crx75gy3ckxfa2eexpsz7zfirupxbywslay5skcgb6dfdtarujymajksipw5xkahnqrhvxeejzosb6hgzcmpb2o5i7oaht6xwkbknm",

}["rate_key"]

room_code = "4thffkrv4arcppzs2a"
room_referance = "qk4srkscrircpwy"
search_id = "ipk3e3zglv6gvk5brzinve3nz4"
hotel_code = "1380443"


kwargs = {
    "booking_items": [
        {
            "room_code": room_code,
            # "rate_key": "4phfnmjx4ius7fstusmwehgw4ljohjxe6gzo3htz3bgrd6pkl2yar67pk5swleeqs5ffz6xtv54bqebxxcygq5m72pobjl6hsgusxq6w4gofftcrzj5d6oatei3oepck7g6sv3tfdazrk74j7g2murp44ky3ewesa34uppc47bey5wxwaewsbai7s6cgd7irblpr2wimajisapw5xkahnqrhvxhebzowb3nwxb4po2ini6okh7zxevzkmcka",
            "rate_key":rate_key,
            "room_reference": room_referance,
            "paxes": [
                {
                    "title": "Mr.",
                    "first_name": "Jijo",
                    "last_name": "Thomas",
                    "email": None,
                    "mobile_no": None,
                    "type": None
                }
            ]
        }
        # ,
        # {
        #     "room_code": room_code,
        #     # "rate_key": "4phfnmjx4ius7fstusmwehgw4ljohjxe6gzo3htz3bgrd6pkl2yar67pk5swleeqs5ffz6xtv54bqebxxcygq5m72pobjl6hsgusxq6w4gofftcrzj5d6oatei3oepck7g6sv3tfdazrk74j7g2murp44ky3ewesa34uppc47bey5wxwaewsbai7s6cgd7irblpr2wimajisapw5xkahnqrhvxhebzowb3nwxb4po2ini6okh7zxevzkmcka",
        #     "rate_key":rate_key,
        #     "room_reference": room_referance,
        #     "paxes": [
        #         {
        #             "title": "Mr.",
        #             "first_name": "Jijo",
        #             "last_name": "Thomas",
        #             "email": None,
        #             "mobile_no": None,
        #             "type": None
        #         }
        #     ]
        # }
    ],
    "check_in": "2025-10-12",
    "check_out": "2025-10-20",
    "group_code": "xgirbylkwb6xtgj647fdssmex6nkls5j6c6ojv3y",
    "city_code": "120919",
    "search_id": search_id,
    "hotel_code": hotel_code,
    "headers": {
        "api-key": "bab29dcd81b9be82284efc966fdbdbaf",
        "Accept": "application/json",
        "Content-Type": "application/json"
    },
    "base_url": "https://api-sandbox.grnconnect.com/api/v3/hotels",
    "holder_details": {
        "title": "Mr.",
        "name": "John",
        "surname": "Doe",
        "email": "john.doe@example.com",
        "phone_number": "9876543210",
        "client_nationality": "In",
        "pan_number": "AAGCB9897B",
        "pan_company_name": "elkanio",
        "fema_declaration": True
    },
    "payment_type": "AT_WEB"
}

def non_bundled_rates_booking(
    booking_items,
    check_in,
    check_out,
    group_code,
    city_code,
    search_id,
    hotel_code,
    headers,
    base_url,
    holder_details,
    payment_type="AT_WEB"
):
    """
    params: holder_details ={
        "client_nationality": client_nationality,
        "email": "info@bookotrip.com",
        "name": "James",
        "phone_number": "6614565589",
        "surname": "Patrick",
        "title": "Mr.",
        "pan_number": "AAGCB9852N",
        "pan_company_name": "BOOKOTRIP INDIA PRIVATE LIMITED",
            }

    booking_items = [{'room_reference':'xxxxx',
    "paxes":pax_list}]
    """


    url = f"{base_url}/bookings"
        
    payload = json.dumps(
        {
    "search_id": search_id,
    "hotel_code": hotel_code,
    "city_code": city_code,
    "group_code": group_code,
    "checkout": check_out,
    "checkin": check_in,
    "booking_comments": "Test booking",
    "payment_type": payment_type,
    "agent_reference": "",
    "booking_items": [
        # {
        # "room_code": room_code,
        # "rate_key": rate_key,
        # "room_reference": room_reference,
        # "rooms": [
        #     {
        #     "paxes": selected_pax
        #     }
        # ]
        # },
        {
        "room_code": i['room_code'],
        "rate_key": i['rate_key'],
        "room_reference": i['room_reference'],
        "rooms": [
            {
            # "no_of_infants": 1,
            "paxes": [{"name": j['first_name'], "surname":j['last_name'], "title":j['title'], "type":"CH" if j['type'] == "CHILD" else "AD"} for j in i['paxes']]
            }
        ]
        }
    for i in booking_items],
    "holder": holder_details
    })

    
    # import pdb;pdb.set_trace()
    print("\n\n non_bundled_rates_booking")
    print("url = ",url)
    print("headers = ",headers)
    print("payload = ",payload)
    response = requests.post(url, headers=headers, data=payload)
    print("response = ",response.text)
    if response.status_code == 200:
        try:
            return response.json()
        except ValueError:
            print("Error: Response is not valid JSON.")
    else:
        print(f"Error:status code: {response.status_code}")
        return response.text


def bundled_rates_booking(
    booking_items,
    check_in,
    check_out,
    group_code,
    city_code,
    search_id,
    hotel_code,
    headers,
    base_url,
    holder_details,
    payment_type="AT_WEB"
):
    
    """
    params: holder_details ={
        "client_nationality": client_nationality,
        "email": "info@bookotrip.com",
        "name": "James",
        "phone_number": "6614565589",
        "surname": "Patrick",
        "title": "Mr.",
        "pan_number": "AAGCB9852N",
        "pan_company_name": "BOOKOTRIP INDIA PRIVATE LIMITED",
            }

    booking_items = [{'room_reference':'xxxxx',
    "paxes":pax_list}]
    """

    url = f"{base_url}/bookings"
    

    payload = json.dumps(
        {
            "agent_reference": "",
            "booking_comments": "Test booking",
            "booking_items": [
                {
                    "rate_key": i['rate_key'],
                    "room_code": i['room_code'],
                    "rooms": [
                        {
                            "paxes": [{"name": j['first_name'], "surname":j['last_name'], "title":j['title'], "type":"CH" if j['type'] == "CHILD" else "AD"} for j in i['paxes']],
                            "room_reference": i['room_reference'],
                        },
                   ],
                }
            for i in booking_items],
            "checkin": check_in,
            "checkout": check_out,
            "city_code": city_code,
            "group_code": group_code,
            "holder": holder_details,
            "hotel_code": hotel_code,
            "payment_type": payment_type,
            "search_id": search_id,
        }
    )
    print("\n\nbundled_rates_booking")
    print("url = ",url)
    print("headers = ",headers)
    print("payload = ",payload)
    response = requests.post(url, headers=headers, data=payload)
    # import pdb;pdb.set_trace()
    print("response = ",response.text)
    if response.status_code == 200:
        try:
            return response.json()
        except ValueError:
            print("Error: Response is not valid JSON.")
    else:
        print(f"Error:status code: {response.status_code},{response.text}")
        return response.text
bundled_rates_booking(**kwargs)
non_bundled_rates_booking(**kwargs)
# Out:
# bundled_rates_booking
# url =  https://api-sandbox.grnconnect.com/api/v3/hotels/bookings
# headers =  {'api-key': 'bab29dcd81b9be82284efc966fdbdbaf', 'Accept': 'application/json', 'Content-Type': 'application/json'}
# ...

# %%
import requests
import json
url =  "https://api-sandbox.grnconnect.com/api/v3/hotels/bookings"
headers =  {'api-key': 'bab29dcd81b9be82284efc966fdbdbaf', 'Accept': 'application/json', 'Content-Type': 'application/json'}


response = requests.post(url, headers=headers, data=json.dumps(payload))
print(response.text)
# Out:
# {"errors":[{"code":1504,"messages":["Invalid Search ID or it might have expired"]}]}

# %%
payload = {'agent_reference': '',
  'booking_comments': 'Test booking',
  'booking_items': [{'rate_key': '4phfnmjw4evclfstusmwehov4pjohjxe6gzo3htz3bgrd6pkl2yar67pk5swleeqs5ffz6xtv54bqebxxcygq5m72pobjl6hsgusxr4fwopu5h2ozj5tmoavei2oepadzggsv3svdexds76o6cy46nmislc3gk4xakeexo2z7zfitwp2aawsnbq5sgfgb6dfdtarujymajksipw5xkahnqrhvxeejyw2lkfdpcpxaoo5a56dgl2aikbc',
    'room_code': '4phv3kr65ircppzs2a',
    'rooms': [
        {
        'paxes': [{'name': 'Arjun',
        'surname': 'Arjun',
        'title': 'Mr.',
        'type': 'AD'}],
        'room_reference': 'qk4srkscrircpwy'},
        {
        'paxes': [{'name': 'Arjun',
        'surname': 'Arjun',
        'title': 'Mr.',
        'type': 'AD'}],
        'room_reference': 'qk4srkscrircpwy'}
        ]
        },
        
        
      ],
  'checkin': '2025-03-28',
  'checkout': '2025-03-30',
  'city_code': '120919',
  'group_code': 'xgirbylkwb6xtgj647fdssmex6nkls5j6c6ojv3y',
  'holder': {'title': 'Mr.',
   'name': 'JIjo',
   'surname': 'Thomas',
   'email': 'admin@bta.com',
   'phone_number': '9995924872',
   'client_nationality': 'In',
   'pan_number': 'AAGCB9897B',
   'pan_company_name': 'Elkanio',
   'fema_declaration': True},
  'hotel_code': '1380443',
  'payment_type': 'AT_WEB',
  'search_id': 'w7dkyikgwcvtcoexfnw7lvzqpq'}

# %%
import requests
import json
url =  "https://api-sandbox.grnconnect.com/api/v3/hotels/bookings"
headers =  {'api-key': 'bab29dcd81b9be82284efc966fdbdbaf', 'Accept': 'application/json', 'Content-Type': 'application/json'}


response = requests.post(url, headers=headers, data=json.dumps(payload))
print(response.text)
# Out:
# {"additional_info":{},"booking_comment":"Test booking","booking_date":"2025-03-27T12:24:31.226621","booking_id":"GRN-SB-202503-1070665","booking_reference":"A8kSD0EWvxivWh14","checkin":"2025-03-27","checkout":"2025-03-29","currency":"INR","holder":{"client_nationality":"In","email":"admin@bta.com","name":"JIjo","pan_number":"AAGCB9897B","phone_number":"9995924872","surname":"Thomas","title":"Mr."},"hotel":{"address":"Jalgaon Road, Town Center, CIDCO, Aurangabad 431003, Maharashtra","booking_items":[{"boarding_details":["Room Only"],"currency":"INR","includes_boarding":true,"non_refundable":true,"price":19642.0,"rate_comments":{"pax_comments":"For this rate the infants will be converted to children with age 1."},"rate_key":"4phfnmjw4evcvfstusmwehov4ln6hjxe6gzo3htz3bgrd6pkl2yar67pk5swleeqs5ffz6xtv54bqebxxcygq5m72pobjl6hsgusxr4fwopu5aclzz4t6pqwfe32sqid7ggrvx2jfabh4ooa7pamqqmls3d3gwxhacfefpk47jhi3xx2aiqslbyrs2ebdgtnaw4gijyiajisipw5xkahnqrbv7fu5m4aatje77h2a6j5s6weisfqy","room_code":"4phv3
# ...

# %%
import requests
easy_link_payload =  """
            <Invoicedata>

            <Invoice InvoiceDate="10-04-25"

            ReftktDt="10-04-25"

            S1Date="10-04-25"

            S2Date="10-04-25"

            S3Date="10-04-25"

            S4Date="10-04-25"

            S5Date="10-04-25"

            S6Date="10-04-25"

            S7Date="10-04-25"

            S8Date="10-04-25"

            S9Date="10-04-25"

            suppcode="GRN"

            tktDt="10-04-25"

            tktNo="A8kSD0EWvxivWh14"

            PaxName="jijo"

            AirCCNo=""

            tkttype="C"

            Sector="Hotel"

            diflg = ""

            SuppType="S"

            CustCode="super admin BTA"

            ServiceType="H"

            HCheckInDate="10-04-25"

            HCheckOutDate="12-04-25"

            SPName="Svenska Mumbai"

            HAddress="F 73/74, Oberoi Complex SAB TV Road Off Link Road Andheri West Mumbai 400 053 SAB TV Road"

            HNoOfRooms="1"

            HNoOfAdult="1"

            HNoOfChild="0"

            Amount="26859.0"

            CustPercGTAX="1342.95"

            CreditType="H" />

</Invoicedata>
"""
headers = {}
easy_link_url =  "http://demo.e-travel.co.in/ws/etbSoap.svc/processEasyBillImp/?sBrCode=000001COK&PortalRefCode=B2BPORTAL"
response = requests.request("POST", easy_link_url, headers = headers, data = easy_link_payload,timeout = 120)
print(response.text)

# %%
import requests
easy_link_payload = """<Invoicedata>\r\n
    <Invoice\r\n
    InvoiceRefID="I050563"\r\n
    InvoiceDate="13/04/2025"\r\n
    XORef="HotelXO1234"\r\n
    SuppType="S"\r\n
    CustCode="A0138"\r\n
    suppcode="A0115"\r\n
    SuppCCIssue="N"\r\n
    ServiceType="H"\r\n
    IntDom="D"\r\n
    PassportNo="A1234567"\r\n
    PassportIssueDate="10/01/2010"\r\n
    PassportExpiryDate="09/01/2030"\r\n
    PlaceOfIssue="Amritsar"\r\n
    tktRef="Ramesh"\r\n
    PaxName="Pax Name"\r\n
    SPName="Name Of Hotel"\r\n
    Remark1="test Remark1"\r\n
    Remark2="test Remark2"\r\n
    HCheckInDate="25/09/2018"\r\n
    HCheckInTime="01:00"\r\n
    HCheckOutDate="27/09/2018"\r\n
    HCheckOutTime="23.30"\r\n
    HConfirmedBy="TP"\r\n
    HConfirmedOn="15/09/2018"\r\n
    HAddress="Panvel"\r\n
    HTelNo="0226485201"\r\n
    HBookingPlan="Business"\r\n
    HRoomType="Delux Suite"\r\n
    HNoOfRooms="2"\r\n
    HNoOfAdult="4"\r\n
    HNoOfChild="3"\r\n
    HNoOfExtra="1"\r\n
    HComingFrom="Dubai"\r\n
    HComingBy="Air"\r\n
    HProceedingTo="Delhi"\r\n
    HProceedingBy="Car"\r\n
    HPkgInclusions="Type All"\r\n
    HPkgExclusions="Exclude All"\r\n
    HPaymentMode="Cash"\r\n
    HRefNo="H001"\r\n
    HIssuedBy="Tejas"\r\n
    HIssuedOn="24/09/2018"\r\n
    HRoomRentPerDay="1000"\r\n
    HSpecialTC="special T and C"\r\n
    Amount="3500.00"\r\n
    TaxA="500.00"\r\n
    TaxB="50.00"\r\n
    TaxC="25.00"\r\n
    OthChgs="0.00"\r\n
    StdComm="150.00"\r\n
    SrvChrgs="200.00"\r\n
    MGTFee="10.00"\r\n
    CustStdComm="50.00"\r\n
    CustSrvChrgs="300.00"\r\n
    CustMGTFee="25.00"\r\n
    PercTDS="5.00"\r\n
    TDS="7.50"\r\n
    CustPercTDS="10.00"\r\n
    CustTDS="20.00"\r\n
    PercGTAX="18.00"\r\n
    GTAX="36.00"\r\n
    CustPercGTAX="18.00"\r\n
    CustGTAX="54.00"\r\n
    CreditType="H"\r\n
    />\r\n
</Invoicedata>"""

headers = {
}
easy_link_url =  "http://demo.e-travel.co.in/ws/etbSoap.svc/processEasyMiscBillImp/?sBrCode=000001COK&PortalRefCode=B2BPORTAL"
response = requests.post(
    easy_link_url,
    headers=headers,
    data=easy_link_payload,
    timeout=120
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/anaconda3/envs/bta-booking/lib/python3.10/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~/anaconda3/envs/bta-booking/lib/python3.10/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import requests
easy_link_payload = """<Invoicedata>\r\n
    <Invoice\r\n
    InvoiceRefID="I050564"\r\n
    InvoiceDate="13/04/2025"\r\n
    XORef="HotelXO1234"\r\n
    SuppType="S"\r\n
    CustCode="A0138"\r\n
    suppcode="A0115"\r\n
    SuppCCIssue="N"\r\n
    ServiceType="H"\r\n
    IntDom="D"\r\n
    tktRef="Ramesh"\r\n
    PaxName="Pax Name"\r\n
    SPName="Name Of Hotel"\r\n
    HCheckInDate="25/09/2018"\r\n
    HCheckInTime="01:00"\r\n
    HCheckOutDate="27/09/2018"\r\n
    HCheckOutTime="23.30"\r\n
    HAddress="Panvel"\r\n
    HTelNo="0226485201"\r\n
    HBookingPlan="Business"\r\n
    HNoOfRooms="2"\r\n
    HNoOfAdult="4"\r\n
    HNoOfChild="3"\r\n
    HNoOfExtra="1"\r\n
    HRoomType="Delux Suite"\r\n
    
    Amount="3500.00"\r\n
    OthChgs="0.00"\r\n
    PercTDS="5.00"\r\n
    TDS="7.50"\r\n
    CustPercTDS="10.00"\r\n
    CustTDS="20.00"\r\n
    PercGTAX="18.00"\r\n
    GTAX="36.00"\r\n
    CustPercGTAX="18.00"\r\n
    CustGTAX="54.00"\r\n
    CreditType="H"\r\n
    />\r\n
</Invoicedata>"""

headers = {
}
easy_link_url =  "http://demo.e-travel.co.in/ws/etbSoap.svc/processEasyMiscBillImp/?sBrCode=000001COK&PortalRefCode=B2BPORTAL"
response = requests.post(
    easy_link_url,
    headers=headers,
    data=easy_link_payload,
    timeout=200
)
print(response.text)
# Out:
# <string xmlns="http://schemas.microsoft.com/2003/10/Serialization/">&lt;RESULT&gt;&#xD;
#   &lt;tkt Status="False" TktNo="" TxnNo="" Desc="Error : Column 'HComingFrom' does not belong to table Invoice." /&gt;&#xD;
# &lt;/RESULT&gt;</string>

# %%
response
# Out:
# <Response [415]>

# %%
data = {
    "InvoiceRefID": "I050567",
    "InvoiceDate": "13/04/2025",
    "XORef": "HotelXO1234",
    "SuppType": "S",
    "CustCode": "A0138",
    "suppcode": "A0115",
    "SuppCCIssue": "N",
    "ServiceType": "H",
    "IntDom": "D",
    # "PassportNo": "A1234567",
    # "PassportIssueDate": "10/01/2010",
    # "PassportExpiryDate": "09/01/2030",
    # "PlaceOfIssue": "Amritsar",
    "tktRef": "Ramesh",
    "PaxName": "Pax Name",
    "SPName": "Name Of Hotel",
    "Remark1": "test Remark1",
    "Remark2": "test Remark2",
    "HCheckInDate": "25/09/2018",
    "HCheckInTime": "",
    "HCheckOutDate": "27/09/2018",
    "HCheckOutTime": "",
    "HConfirmedBy": "",
    "HConfirmedOn": "",
    "HAddress": "Panvel",
    "HTelNo": "",
    "HBookingPlan": "Business",
    "HRoomType": "Delux Suite",
    "HNoOfRooms": "2",
    "HNoOfAdult": "4",
    "HNoOfChild": "3",
    "HNoOfExtra": "",
    "HComingFrom": "",
    "HComingBy": "",
    "HProceedingTo": "",
    "HProceedingBy": "",
    "HPkgInclusions": "",
    "HPkgExclusions": "",
    "HPaymentMode": "",
    "HRefNo": "H001",
    "HIssuedBy": "",
    "HIssuedOn": "",
    "HRoomRentPerDay": "",
    "HSpecialTC": "",
    "Amount": "3500.00",
    "TaxA": "500.00",
    "TaxB": "50.00",
    "TaxC": "25.00",
    "OthChgs": "0.00",
    "StdComm": "150.00",
    "SrvChrgs": "200.00",
    "MGTFee": "10.00",
    "CustStdComm": "50.00",
    "CustSrvChrgs": "300.00",
    "CustMGTFee": "25.00",
    "PercTDS": "",
    "TDS": "",
    "CustPercTDS": "",
    "CustTDS": "",
    "PercGTAX": "18.00",
    "GTAX": "36.00",
    "CustPercGTAX": "18.00",
    "CustGTAX": "54.00",
    "CreditType": "H"
}

easy_link_payload = "<Invoicedata>\r\n"
easy_link_payload += "    <Invoice\r\n"

for key, value in data.items():
    easy_link_payload += f'    {key}="{value}"\r\n'

easy_link_payload += "    />\r\n</Invoicedata>"

print(easy_link_payload)

headers = {
}
easy_link_url =  "http://demo.e-travel.co.in/ws/etbSoap.svc/processEasyMiscBillImp/?sBrCode=000001COK&PortalRefCode=B2BPORTAL"
response = requests.post(
    easy_link_url,
    headers=headers,
    data=easy_link_payload,
    timeout=200
)
print(response.text)
# Out:
# <Invoicedata>
#     <Invoice
#     InvoiceRefID="I050567"
#     InvoiceDate="13/04/2025"
#     XORef="HotelXO1234"
#     SuppType="S"
#     CustCode="A0138"
#     suppcode="A0115"
#     SuppCCIssue="N"
#     ServiceType="H"
#     IntDom="D"
#     tktRef="Ramesh"
#     PaxName="Pax Name"
#     SPName="Name Of Hotel"
#     Remark1="test Remark1"
#     Remark2="test Remark2"
#     HCheckInDate="25/09/2018"
#     HCheckInTime=""
#     HCheckOutDate="27/09/2018"
#     HCheckOutTime=""
#     HConfirmedBy=""
#     HConfirmedOn=""
#     HAddress="Panvel"
#     HTelNo=""
#     HBookingPlan="Business"
#     HRoomType="Delux Suite"
#     HNoOfRooms="2"
#     HNoOfAdult="4"
#     HNoOfChild="3"
#     HNoOfExtra="1"
#     HComingFrom="Dubai"
#     HComingBy="Air"
#     HProceedingTo="Delhi"
#     HProceedingBy="Car"
#     HPkgInclusions="Type All"
#     HPkgExclusions="Exclude All"
#     HPaymentMode="Cash"
#     HRefNo="H001"
#     HIssuedBy="Tejas"
#     HIssuedOn="24/09/2018"
# ...

# %%
import requests	
url = "https://api-sandbox.grnconnect.com/api/v3/hotels/bookings/FLqNI37Wdm1VuQfe"
body = {
    "comments":"cancellation comments",
    "reason": 13
}
headers =  {'api-key': 'bab29dcd81b9be82284efc966fdbdbaf', 'Accept': 'application/json', 'Content-Type': 'application/json'}

response = requests.delete(url, json=body, headers=headers)
print(response.text)
# Out:
# {"errors":[{"code":6000,"messages":["This booking doesn't support cancellation from API."]}]}

# %%
headers =  {'api-key': '5266b1c245a9f8a6372ead13fe1db1d6', 'Accept': 'application/json', 'Content-Type': 'application/json'}
url =  https://v4-api.grnconnect.com/api/v3/hotels/api/v3/hotels/availability
payload =  {"rooms": [{"adults": 1, "children_ages": []}], "hotel_codes": ["1204427", "ADYKA03V", "ADYWLCAM", "AEYWLAAE", "ASYWLAAG", "BBYWLAAZ", "BKZMHABI", "CTYWLAAF", "DKYWLAAT", "HBYWL002", "HBYWLAAI", "HDYWLAAS", "HDZMHAAC", "RIZMHAAK", "SJYKAACL", "TEYWLAAW", "TEZMHAAB", "TVYWLAAJ", "TZYWLAAB", "UXYWLAAP", "VJZMH00G", "XDYWLAAE", "1096972", "306381", "622475", "124665", "171674"], "currency": "INR", "client_nationality": "IN", "checkout": "2025-04-17", "checkin": "2025-04-15", "purpose_of_travel": 2, "rates": "comprehensive"}
response =  Something went wrong
